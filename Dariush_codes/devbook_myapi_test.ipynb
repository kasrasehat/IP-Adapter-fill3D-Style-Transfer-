# %%
from myapi import image_to_base64, base64_to_image, MyAPIClient
from PIL import Image
import requests 
from typing import Literal

# %%
image = Image.open("image (9).png")
image.thumbnail((512, 512))
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x342>

# %%
url = 'http://localhost:8000'
# flip-image (POST)



client = MyAPIClient(url)
client.flip_image(image, direction="vertical")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x342>
